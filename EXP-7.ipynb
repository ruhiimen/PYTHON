# %%
clr1={"blue","yellow","orange"}
clr2={"black","yellow","red"}
diff=clr1 - clr2
print("color set is:",diff)
# Out:
# color set is: {'orange', 'blue'}

# %%
clr1={"blue","yellow","orange"}
clr2={"black","yellow","red"}
colors=clr1 | clr2
print("color set is:",colors)
# Out:
# color set is: {'orange', 'red', 'black', 'blue', 'yellow'}
