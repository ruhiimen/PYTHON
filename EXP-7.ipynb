# %%
clr1=set(input("Enter colors:")).split(',')
clr2=set(input("Enter colors:")).split(',')
diff=clr1 - clr2
print("color set is:",diff)

# %%
clr1=input("Enter colors:").split(',')
clr2=input("Enter colors:").split(',')
colors=clr1 | clr2
print("color set is:",colors)
# Out:
# Enter colors: red,green,yellow
# Enter colors: red,blue,black,yellow
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 3
#       1 clr1=input("Enter colors:").split(',')
#       2 clr2=input("Enter colors:").split(',')
# ----> 3 colors=clr1 | clr2
#       4 print("color set is:",colors)
#
# TypeError: unsupported operand type(s) for |: 'list' and 'list'
