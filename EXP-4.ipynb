# %%
list=input("Enter colors:").split(',')
print("the First color is :",list[0])
print("the Second color is :",list[-1])
# Out:
# Enter colors: blue,red,green,yellow,black
# the First color is : blue
# the Second color is : black

# %%
filename=input("Enter filename:")
extension=filename.split(".")[-1]
print("the extension is:",extension)
# Out:
# Enter filename: list.py
# the extension is: py

# %%
a=input("Enter numbers:")
b=[int(num.strip())for num in a.split(',')]
total=sum(b)
print("sum is :",total)
# Out:
# Enter numbers: 1,2,3,4
# sum is : 10
