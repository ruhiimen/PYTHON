# %%
#to sort dictionary in ascending and descending order
roll=input("Enter 5 roll numbers(space seperated)").split(",")
name=input("Enter 5 student names(space seperated)").split(",")
d=dict(zip(roll,name))
print("Dictionary",d)
print("Dictionary in ascending order",dict(sorted(d.items())))
print("Dictionary in descending order",dict(sorted(d.items(),reverse=True)))
# Out:
# Enter 5 roll numbers(space seperated) 1,2,3,4,5
# Enter 5 student names(space seperated)  siya,joe,niya,kian,rae
# Dictionary {'1': ' siya', '2': 'joe', '3': 'niya', '4': 'kian', '5': 'rae'}
# Dictionary in ascending order {'1': ' siya', '2': 'joe', '3': 'niya', '4': 'kian', '5': 'rae'}
# Dictionary in descending order {'5': 'rae', '4': 'kian', '3': 'niya', '2': 'joe', '1': ' siya'}

# %%
#accept two dictionaries and merge and display them
d1=dict(zip(input("Enter 3 roll numbers").split(","),input("Enter 3 student names").split(",")))
d2=dict(zip(input("Enter 2 roll numbers").split(","),input("Enter 2 student names").split(",")))
print("Dictionary1:",d1)
print("Dictionary2: ",d2)
d1.update(d2)
print(" Merged Dictionary:",d1)
# Out:
# Enter 3 roll numbers 1,2,3
# Enter 3 student names rae,ben,liya
# Enter 2 roll numbers 4,5
# Enter 2 student names siya,kian
# Dictionary1: {'1': 'rae', '2': 'ben', '3': 'liya'}
# Dictionary2:  {'4': 'siya', '5': 'kian'}
#  Merged Dictionary: {'1': 'rae', '2': 'ben', '3': 'liya', '4': 'siya', '5': 'kian'}
