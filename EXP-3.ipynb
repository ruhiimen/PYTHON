# %%
#change a given string to new sting
a=input("Enter a string:")
b=a[-1]+a[1:-1]+a[0]
print("new string:",b)
# Out:
# Enter a string:python
# new string: nythop

# %%
#to get a string made of the 1st and last characters
a=input("Enter a string:")
b=a[1:2]+a[-2:]
print("New string:",b)
# Out:
# Enter a string:python
# New string: yon

# %%
#swapping
s1=input("Enter a string:")
s2=input("Enter a string:")
a=s2[0]+s1[1:]
b=s1[0]+s2[1:]
print("new string:",a,b)
# Out:
# Enter a string:hello
# Enter a string:world
# new string: wello horld

# %%
a=input("Enter a string:")
b=a[0]+a[1:].replace(a[0],"$")
print("new string:",b)
# Out:
# Enter a string:onion
# new string: oni$n
