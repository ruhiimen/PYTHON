# %%
a='python'
b=a[-1]+a[1:-1]+a[0]
print("new string:",b)
# Out:
# new string: nythop

# %%
a='python'
b=a[0:2]+a[4:6]
print("New string:",b)
# Out:
# New string: pyon

# %%
s1='Hello'
s2='World'
print("Swapped string:",s1,"",s2)
# Out:
# Swapped string: Hello  World

# %%
a=input("Enter a string:")
b=a[0]+a[1:].replace(a[0],"$")
print("new string:",b)
# Out:
# Enter a string:onion
# new string: oni$n
